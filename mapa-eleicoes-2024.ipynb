# %% [markdown]
# **Alunos: Alex Henrique, Gabriel Pedrotti e Marco Antonio**

# %%
# !pip install folium

# %%
import folium
import pandas as pd

file_path = '/content/consulta_cand_2024_SC.csv'

df = pd.read_csv(file_path, encoding='latin-1', delimiter=';')

df_prefeitos = df[['NM_UE', 'NM_CANDIDATO', 'SG_PARTIDO', 'DS_CARGO', 'DS_SIT_TOT_TURNO']]

municipios_coordenadas = {
    'ABDON BATISTA': [-27.6126, -51.0233],
    'ABELARDO LUZ': [-26.5716, -52.3229],
    'AGROLÂNDIA': [-27.4087, -49.8226],
    'AGRONÔMICA': [-27.266, -49.708],
    'ÁGUA DOCE': [-26.9984, -51.552],
    'ÁGUAS DE CHAPECÓ': [-27.0754, -52.9808],
    'ÁGUAS FRIAS': [-26.8794, -52.8569],
    'ÁGUAS MORNAS': [-27.6963, -48.8246],
    'ALFREDO WAGNER': [-27.7007, -49.3271],
    'ALTO BELA VISTA': [-27.4333, -51.9044],
    'ANCHIETA': [-26.5389, -53.331],
    'ANGELINA': [-27.5704, -48.9874],
    'ANITA GARIBALDI': [-27.6897, -51.1278],
    'ANITÁPOLIS': [-27.9036, -49.1315],
    'ANTÔNIO CARLOS': [-27.5199, -48.7662],
    'APIÚNA': [-27.0369, -49.3881],
    'ARABUTÃ': [-27.1586, -52.1433],
    'ARAQUARI': [-26.375, -48.7189],
    'ARARANGUÁ': [-28.9356, -49.4918],
    'ARMAZÉM': [-28.2448, -49.0214],
    'AURORA': [-27.3097, -49.6292],
    'BALNEÁRIO ARROIO DO SILVA': [-28.9805, -49.4236],
    'BALNEÁRIO CAMBORIÚ': [-26.9926, -48.6352],
    'BALNEÁRIO BARRA DO SUL': [-26.4591, -48.6123],
    'BALNEÁRIO GAIVOTA': [-29.1526, -49.5845],
    'BANDEIRANTE': [-26.7704, -53.6413],
    'BARRA BONITA': [-26.6549, -53.44],
    'BARRA VELHA': [-26.637, -48.6932],
    'BELA VISTA DO TOLDO': [-26.2746, -50.4666],
    'BELMONTE': [-26.8432, -53.5758],
    'BENEDITO NOVO': [-26.7819, -49.3594],
    'BIGUAÇU': [-27.496, -48.6594],
    'BLUMENAU': [-26.915, -49.071],
    'BOCAINA DO SUL': [-27.7459, -49.9427],
    'BOM JARDIM DA SERRA': [-28.3375, -49.6379],
    'BOM JESUS': [-26.7324, -52.391],
    'BOM JESUS DO OESTE': [-26.6928, -53.0962],
    'BOM RETIRO': [-27.7993, -49.4875],
    'BOMBINHAS': [-27.136, -48.514],
    'BOTUVERÁ': [-27.2004, -49.0688],
    'BRAÇO DO NORTE': [-28.2682, -49.1704],
    'BRAÇO DO TROMBUDO': [-27.3586, -49.8821],
    'BRUNÓPOLIS': [-27.3055, -50.868],
    'BRUSQUE': [-27.0977, -48.9106],
    'CAÇADOR': [-26.7757, -51.012],
    'TIMBÓ GRANDE': [-26.613, -50.6608],
    'TRÊS BARRAS': [-26.1059, -50.3191],
    'TREVISO': [-28.5093, -49.4638],
    'TREZE DE MAIO': [-28.5531, -49.156],
    'TREZE TÍLIAS': [-27.0026, -51.4084],
    'TROMBUDO CENTRAL': [-27.2926, -49.7934],
    'TUBARÃO': [-28.4713, -49.0144],
    'TUNÁPOLIS': [-26.9681, -53.6446],
    'TURVO': [-28.9312, -49.6834],
    'UNIÃO DO OESTE': [-26.761, -52.8547],
    'URUBICI': [-28.0168, -49.5923],
    'URUPEMA': [-28.2913, -49.8726],
    'URUSSANGA': [-28.5166, -49.3232],
    'VARGEÃO': [-26.8632, -52.1547],
    'VARGEM': [-27.4869, -50.9725],
    'VARGEM BONITA': [-27.004, -51.7409],
    'VIDAL RAMOS': [-27.388, -49.3592],
    'VIDEIRA': [-27.0081, -51.1505],
    'VITOR MEIRELES': [-26.8782, -49.8326],
    'WITMARSUM': [-26.9275, -49.7946],
    'XANXERÊ': [-26.8765, -52.4031],
    'XAVANTINA': [-27.0661, -52.343],
    'XAXIM': [-26.9594, -52.5374],
    'ZORTÉA': [-27.4517, -51.5518]
}


partido_cores = {
    'PSD': 'blue',
    'AVANTE': 'orange',
    'PL': 'darkblue',
    'PODE': 'lightblue',
    'PRTB': 'purple',
    'REPUBLICANOS': 'red',
    'NOVO': 'orange',
    'PP': 'lightgreen',
    'PRD': 'darkred',
    'MOBILIZA': 'brown',
    'PSB': 'yellow',
    'UNIÃO': 'blue',
    'PDT': 'darkred',
    'MDB': 'green',
    'DC': 'darkgray',
    'SOLIDARIEDADE': 'orange',
    'PMB': 'pink',
    'AGIR': 'cyan',
    'PSDB': 'darkblue',
    'CIDADANIA': 'lightgreen',
    'PT': 'red',
    'PC do B': 'darkred',
    'PSOL': 'yellow',
    'PV': 'green',
    'REDE': 'lightgreen',
    'UP': 'lightred',
    'PCO': 'black',
    'PSTU': 'darkyellow'
}


mapa = folium.Map(location=[-27.2423, -50.2189], zoom_start=7)

for index, row in df_prefeitos.iterrows():
    municipio = row['NM_UE']
    prefeito = row['NM_CANDIDATO']
    partido = row['SG_PARTIDO']
    cargo = row['DS_CARGO']
    eleito = row['DS_SIT_TOT_TURNO'] in ['ELEITO POR QP', 'ELEITO POR MÉDIA', 'ELEITO']

    if municipio in municipios_coordenadas and cargo == 'PREFEITO' and eleito:
        lat, lon = municipios_coordenadas[municipio]
        cor = partido_cores.get(partido, 'gray')

        folium.CircleMarker(
            location=[lat, lon],
            radius=10,
            color=cor,
            fill=True,
            fill_color=cor,
            fill_opacity=0.7,
            popup=f"Município: {municipio}<br>Prefeito: {prefeito}<br>Partido: {partido}"
        ).add_to(mapa)

mapa.save("mapa_prefeitos_santa_catarina.html")
# Baixe a abra o arquivo .html gerado para visualizar o mapa.
